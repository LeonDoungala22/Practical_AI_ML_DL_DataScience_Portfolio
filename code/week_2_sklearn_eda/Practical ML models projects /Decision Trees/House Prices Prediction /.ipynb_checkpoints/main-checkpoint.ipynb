# %% [markdown]
# # House Prices: Advanced Regression Techniques

# %% [markdown]
# ![depositphotos_49099713-stock-photo-counting-property-prices.jpeg](attachment:depositphotos_49099713-stock-photo-counting-property-prices.jpeg)
