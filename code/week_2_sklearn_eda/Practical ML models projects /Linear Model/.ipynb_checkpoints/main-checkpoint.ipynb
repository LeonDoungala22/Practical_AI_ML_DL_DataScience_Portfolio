# %% [markdown]
# # Salary Prediction using Linear Regression

# %% [markdown]
# ### 1. Data Exploration

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')  # to avoud warnings

# %%
#Load and analyze the dataset.

data = pd.read_csv("Datasets/Salary_dataset.csv")
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df = pd.DataFrame(data)   #convert into dataframe

# %%
#Remove irrelevant columns 

df = df.drop("Unnamed: 0", axis=1)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
df.shape
# Out:
# (30, 2)

# %%
# Handle missing values.
       # missinggno is used to visualized missing values
import missingno as msno 

msno.matrix(df)

df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# **NB: No missing values detected**

# %%
#Explore statistical summary.

df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %% [markdown]
# ### 2. Data Visualization

# %%
#Create visualizations (scatter plots, histograms) for Salary and features.

# %%
# Sort the DataFrame by salary values
df_sorted = df.sort_values(by='Salary')

# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(df_sorted['Salary'], bins=30, color='skyblue', edgecolor='black')

# Calculate and plot the median salary
median_salary = df_sorted['Salary'].median()
plt.axvline(median_salary, color='red', linestyle='dashed', linewidth=2, label=f'Median Salary: {median_salary:.2f} €')

# Calculate and plot the mean salary
mean_salary = df_sorted['Salary'].mean()
plt.axvline(mean_salary, color='green', linestyle='dashed', linewidth=2, label=f'Mean Salary: {mean_salary:.2f} €')

# Adding labels and title
plt.title('Sorted Salary Distribution with Median and Mean Lines')
plt.xlabel('Salary')
plt.ylabel('Frequency')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
df[['YearsExperience', 'Salary']].sort_values(by="YearsExperience", inplace=True)

plt.figure(figsize=(10, 6))
plt.plot(df['YearsExperience'], df['Salary'], marker='o', linestyle='-', color='b')
plt.title('Salary vs Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %%
# Sort the DataFrame by both 'YearsExperience' and 'Salary'
df_sorted = df.sort_values(by=['YearsExperience', 'Salary'])

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Create a scatter plot with customized markers
ax.scatter(df_sorted['YearsExperience'], df_sorted['Salary'], color='skyblue', edgecolor='black', s=50, label='Data Points') 

# Add labels and title

ax.set_title('Salary vs Years of Experience')
ax.set_xlabel('Years of Experience')
ax.set_ylabel('Salary')

# Show legend
ax.legend()

# Display the plot
plt.show()

# %%
#Visualize the correlation matrix.

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame
correlation_matrix = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create a heatmap using Seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)

# Add title
plt.title('Correlation Matrix')

# Show the plot
plt.show()

# %% [markdown]
# **PS : These graphs consistently affirm a positive correlation between salary and years of experience**

# %% [markdown]
# ### 3- Linear Regression Model

# %%
#Split data into training and testing sets.

# %%
y = df["Salary"]
X = df.drop(["Salary"] , axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape , X_test.shape
# Out:
# ((20, 1), (10, 1))

# %%
# Implement simple linear regression.

# %%
from sklearn import linear_model

# %%
from sklearn import linear_model

#Create a Linear model 
reg = linear_model.LinearRegression()

#Train the model 
reg.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
# Predict the model on the test set
y_pred = reg.predict(X_test)

# Print the predictions
print('Predicted salaries:')
for predicted_salary in y_pred:
    print( f'{predicted_salary:.2f} €')
# Out:
# Predicted salaries:
# 115815.31 €
# 71512.93 €
# 102618.85 €
# 75283.34 €
# 55488.66 €
# 60201.68 €
# 122413.53 €
# 107331.87 €
# 63029.49 €
# 35693.98 €

# %%
# Assuming you have a DataFrame with 'YearsExperience' column
experience_3_years = pd.DataFrame({'YearsExperience': [3]})

# Predict for 3 years of experience
predicted_salary_3_years = reg.predict(experience_3_years)

# Print the predicted salary for 3 years of experience
print(f'Predicted salary for 3 years of experience: {predicted_salary_3_years[0]:.2f} €')
# Out:
# Predicted salary for 3 years of experience: 52660.85 €
