# %% [markdown]
# # Ensemble Learning Focus Assignment: Diabetes Prediction and Characterization

# %% [markdown]
# ![is-diabetes-genetic-5112506_final-04c9aa844032499fbcd37bc36df78b38.jpeg](attachment:is-diabetes-genetic-5112506_final-04c9aa844032499fbcd37bc36df78b38.jpeg)

# %% [markdown]
# # Diabetes Types Overview
#
# In the realm of diabetes, various types exist, each with distinct characteristics and risk factors.
#
# ## - Types of Diabetes
#
# | Type | Description                                     | Characteristics                                     | Risk Factors                                       |
# |:----:|:-----------------------------------------------:|:---------------------------------------------------:|:---------------------------------------------------:|
# | **Type 1**        | Autoimmune disorder; immune system attacks insulin-producing cells. | - Diagnosed in childhood. <br> - Requires insulin injections. | - Genetic predisposition. <br> - Viral infections. |
# | **Type 2**        | Insulin resistance, impaired production.          | - Usually in adulthood. <br> - Linked to poor lifestyle. | - Obesity. <br> - Family history. <br> - Age. |
# | **Gestational**   | Develops during pregnancy; resolves post-childbirth. | - Elevated blood sugar during pregnancy. | - Overweight/obesity in pregnancy. <br> - Family history. |
# | **LADA**          | Slow-onset autoimmune diabetes in adults.        | - Resembles Type 1 in adults. <br> - Progresses slowly. | - Autoimmune factors. <br> - Family history. |
#
# ***Note:** This table provides a concise summary of key information for each diabetes type.*
# ____

# %% [markdown]
# # Objective
#
# In this Markdown document, our primary goal is to conduct a comprehensive analysis of the Pima Indians Diabetes Database using advanced **ensemble learning techniques**. We will apply methods such as **Gradient Boosting, Random Forests, Bagging, Voting, and Stacking** to predict and characterize diabetes, with a focus on differentiating between diabetes types.
#
# ## Data Source
#
# The original dataset is sourced from the [Biostatistics program at Vanderbilt University](https://www.vanderbilt.edu/lapop/raw-data.php). For additional context about the Biostatistics program, you can explore their [official website](https://www.vanderbilt.edu/biostatistics-graduate/current-program/rationale-and-overview/).
#
# The dataset for this analysis is also available on [Data World](https://data.world/informatics-edu/diabetes-prediction/workspace/file?filename=Diabetes_Classification.xlsx). For additional context about the dataset, please refer to the provided [Data World link](https://data.world/informatics-edu/diabetes-prediction/workspace/file?filename=Diabetes_Classification.xlsx).
#
# ## Dataset Overview
# - **Patients:** Several hundred rural African-American patients.
# - **Raw Data:** The [Diabetes_Classification.xlsx](https://data.world/informatics-edu/diabetes-prediction/workspace/file?filename=Diabetes_Classification.xlsx) file contains cleaned and manipulated data, including patients with missing data, suitable for descriptive statistics.
# - **Data Dictionary:** Detailed column explanations are available in the [Diabetes Data Dictionary](./Dataset/DiabetesDataDictionary.md).
#
# ## Data Cleaning and Manipulation
#
# - The Diabetes_Classification file underwent cleaning and manipulation.
# - Patients without hemoglobin A1c measurements were excluded.
# - Those with hemoglobin A1c levels ≥ 6.5 were labeled as diabetic (diabetes = yes).
# - Out of 390 patients, 60 were identified as diabetic.
# - A code book detailing the variables is available in one of the tabs.
#
# ## Machine Learning Task
#
# We aim to use a machine learning classification algorithm to predict diabetes based on demographic and laboratory variables. Key objectives include:
#
# - Identifying the strongest predictors within the dataset.
# - Exploring prediction strength when excluding the glucose variable .
#
# By addressing these goals, we aim to contribute valuable insights to diabetes prediction and showcase the effectiveness of ensemble learning techniques in healthcare analytics.
#
# ____

# %% [markdown]
# ## 1. Data Exploration and Preprocessing:
# - Load the [Diabetes Classification Dataset](https://data.world/informatics-edu/diabetes-prediction/workspace/file?filename=Diabetes_Classification.xlsx) and conduct an initial exploration.
# - Address missing values, outliers, and perform exploratory data analysis (EDA).
# - Utilize EDA visualizations to gain insights into key features.
# ___

# %% [markdown]
# - Load the Pima Indians Diabetes Database and conduct an initial exploration.

# %%
#Import libreries 

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, BaggingClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score


import DataViz 
import missingno as msno

import warnings 

warnings.filterwarnings("ignore")

# %%
# Read the dataset into a pandas DataFrame
df = pd.read_excel("Dataset/Diabetes_Classification.xlsx")

# Display the first few rows of the DataFrame
df
# Out:
#      Patient number  Cholesterol  Glucose  HDL Chol  Chol/HDL ratio  Age  \
# 0                 1          193       77        49             3.9   19
# 1                 2          146       79        41             3.6   19
# 2                 3          217       75        54             4.0   20
# 3                 4          226       97        70             3.2   20
# 4                 5          164       91        67             2.4   20
# ..              ...          ...      ...       ...             ...  ...
# 385             386          227      105        44             5.2   83
# 386             387          226      279        52             4.3   84
# 387             388          301       90       118             2.6   89
# 388             389          232      184       114             2.0   91
# 389             390          165       94        69             2.4   92
#
#      Gender  Height  Weight   BMI  Systolic BP  Diastolic BP  waist  hip  \
# 0    female      61     119  22.5          118            70     32   38
# 1    female      60     135  26.4          108            58     33   40
# 2    female      67     187  29.3          110            72     40   45
# 3    female      64     114  19.6          122            64     31   39
# 4    female      70     141  20.2          122            86     32   39
# ..      ...     ...     ...   ...          ...           ...    ...  ...
# 385  female      59     125  25.2          150            90     35   40
# 386  female      60     192  37.5          144            88     41   48
# 387  female      61     115  21.7          218            90     31   41
# 388  female      61     127  24.0          170            82     35   38
# 389  female      62     217  39.7          160            82     51   51
#
#      Waist/hip ratio     Diabetes  Unnamed: 16  Unnamed: 17
# 0               0.84  No diabetes          6.0          6.0
# 1               0.83  No diabetes          NaN          NaN
# 2               0.89  No diabetes          NaN          NaN
# 3               0.79  No diabetes          NaN          NaN
# 4               0.82  No diabetes          NaN          NaN
# ..               ...          ...          ...          ...
# 385             0.88  No diabetes          NaN          NaN
# 386             0.85     Diabetes          NaN          NaN
# 387             0.76  No diabetes          NaN          NaN
# 388             0.92     Diabetes          NaN          NaN
# 389             1.00  No diabetes          NaN          NaN
#
# [390 rows x 18 columns]

# %% [markdown]
# - Dataset Attribute Encoding , and processed Overview based on Documentation

# %% [markdown]
# **NB:** [Columns Names Descriptions](./Dataset/ColumnsNameDescriptions.md)

# %% [markdown]
# - Initial exploration

# %%
#Convert into dataFrame 

df = pd.DataFrame(df , columns=df.columns)

# %%
#head
df.head()
# Out:
#    Patient number  Cholesterol  Glucose  HDL Chol  Chol/HDL ratio  Age  \
# 0               1          193       77        49             3.9   19
# 1               2          146       79        41             3.6   19
# 2               3          217       75        54             4.0   20
# 3               4          226       97        70             3.2   20
# 4               5          164       91        67             2.4   20
#
#    Gender  Height  Weight   BMI  Systolic BP  Diastolic BP  waist  hip  \
# 0  female      61     119  22.5          118            70     32   38
# 1  female      60     135  26.4          108            58     33   40
# 2  female      67     187  29.3          110            72     40   45
# 3  female      64     114  19.6          122            64     31   39
# 4  female      70     141  20.2          122            86     32   39
#
#    Waist/hip ratio     Diabetes  Unnamed: 16  Unnamed: 17
# 0             0.84  No diabetes          6.0          6.0
# 1             0.83  No diabetes          NaN          NaN
# 2             0.89  No diabetes          NaN          NaN
# 3             0.79  No diabetes          NaN          NaN
# 4             0.82  No diabetes          NaN          NaN

# %%
#tails

df.tail()
# Out:
#      Patient number  Cholesterol  Glucose  HDL Chol  Chol/HDL ratio  Age  \
# 385             386          227      105        44             5.2   83
# 386             387          226      279        52             4.3   84
# 387             388          301       90       118             2.6   89
# 388             389          232      184       114             2.0   91
# 389             390          165       94        69             2.4   92
#
#      Gender  Height  Weight   BMI  Systolic BP  Diastolic BP  waist  hip  \
# 385  female      59     125  25.2          150            90     35   40
# 386  female      60     192  37.5          144            88     41   48
# 387  female      61     115  21.7          218            90     31   41
# 388  female      61     127  24.0          170            82     35   38
# 389  female      62     217  39.7          160            82     51   51
#
#      Waist/hip ratio     Diabetes  Unnamed: 16  Unnamed: 17
# 385             0.88  No diabetes          NaN          NaN
# 386             0.85     Diabetes          NaN          NaN
# 387             0.76  No diabetes          NaN          NaN
# 388             0.92     Diabetes          NaN          NaN
# 389             1.00  No diabetes          NaN          NaN

# %%
#shape

df.shape
# Out:
# (390, 18)

# %%
df['Diabetes'].value_counts()
# Out:
# Diabetes
# No diabetes    330
# Diabetes        60
# Name: count, dtype: int64

# %%
#data type

df.dtypes.value_counts()
# Out:
# int64      11
# float64     5
# object      2
# Name: count, dtype: int64

# %%
#Describe

df.describe()
# Out:
#        Patient number  Cholesterol     Glucose    HDL Chol  Chol/HDL ratio  \
# count      390.000000   390.000000  390.000000  390.000000      390.000000
# mean       195.500000   207.230769  107.338462   50.266667        4.524615
# std        112.727548    44.666005   53.798188   17.279069        1.736634
# min          1.000000    78.000000   48.000000   12.000000        1.500000
# 25%         98.250000   179.000000   81.000000   38.000000        3.200000
# 50%        195.500000   203.000000   90.000000   46.000000        4.200000
# 75%        292.750000   229.000000  107.750000   59.000000        5.400000
# max        390.000000   443.000000  385.000000  120.000000       19.300000
#
#               Age      Height      Weight         BMI  Systolic BP  \
# count  390.000000  390.000000  390.000000  390.000000   390.000000
# mean    46.774359   65.951282  177.407692   28.775641   137.133333
# std     16.435911    3.918867   40.407824    6.600915    22.859528
# min     19.000000   52.000000   99.000000   15.200000    90.000000
# 25%     34.000000   63.000000  150.250000   24.100000   122.000000
# 50%     44.500000   66.000000  173.000000   27.800000   136.000000
# 75%     60.000000   69.000000  200.000000   32.275000   148.000000
# max     92.000000   76.000000  325.000000   55.800000   250.000000
#
#        Diastolic BP       waist         hip  Waist/hip ratio  Unnamed: 16  \
# count    390.000000  390.000000  390.000000       390.000000          1.0
# mean      83.289744   37.869231   42.992308         0.881385          6.0
# std       13.498192    5.760947    5.664342         0.073212          NaN
# min       48.000000   26.000000   30.000000         0.680000          6.0
# 25%       75.000000   33.000000   39.000000         0.830000          6.0
# 50%       82.000000   37.000000   42.000000         0.880000          6.0
# 75%       90.000000   41.000000   46.000000         0.930000          6.0
# max      124.000000   56.000000   64.000000         1.140000          6.0
#
#        Unnamed: 17
# count          1.0
# mean           6.0
# std            NaN
# min            6.0
# 25%            6.0
# 50%            6.0
# 75%            6.0
# max            6.0

# %% [markdown]
# - Address missing values, outliers, and perform exploratory data analysis (EDA).

# %%
#Missing values 

df.isnull().sum()
# Out:
# Patient number       0
# Cholesterol          0
# Glucose              0
# HDL Chol             0
# Chol/HDL ratio       0
# Age                  0
# Gender               0
# Height               0
# Weight               0
# BMI                  0
# Systolic BP          0
# Diastolic BP         0
# waist                0
# hip                  0
# Waist/hip ratio      0
# Diabetes             0
# Unnamed: 16        389
# Unnamed: 17        389
# dtype: int64

# %%
#Remove unsued colunms 

df.drop('Unnamed: 16' , axis=1 , inplace=True)
df.drop('Unnamed: 17' , axis=1 , inplace=True)
df.drop('Patient number' , axis=1 , inplace=True)

# %%
#Visualize missing values 

msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# **NO MISSING VALUES !**

# %%
#Drop duplicated 

df.drop_duplicates()
# Out:
#      Cholesterol  Glucose  HDL Chol  Chol/HDL ratio  Age  Gender  Height  \
# 0            193       77        49             3.9   19  female      61
# 1            146       79        41             3.6   19  female      60
# 2            217       75        54             4.0   20  female      67
# 3            226       97        70             3.2   20  female      64
# 4            164       91        67             2.4   20  female      70
# ..           ...      ...       ...             ...  ...     ...     ...
# 385          227      105        44             5.2   83  female      59
# 386          226      279        52             4.3   84  female      60
# 387          301       90       118             2.6   89  female      61
# 388          232      184       114             2.0   91  female      61
# 389          165       94        69             2.4   92  female      62
#
#      Weight   BMI  Systolic BP  Diastolic BP  waist  hip  Waist/hip ratio  \
# 0       119  22.5          118            70     32   38             0.84
# 1       135  26.4          108            58     33   40             0.83
# 2       187  29.3          110            72     40   45             0.89
# 3       114  19.6          122            64     31   39             0.79
# 4       141  20.2          122            86     32   39             0.82
# ..      ...   ...          ...           ...    ...  ...              ...
# 385     125  25.2          150            90     35   40             0.88
# 386     192  37.5          144            88     41   48             0.85
# 387     115  21.7          218            90     31   41             0.76
# 388     127  24.0          170            82     35   38             0.92
# 389     217  39.7          160            82     51   51             1.00
#
#         Diabetes
# 0    No diabetes
# 1    No diabetes
# 2    No diabetes
# 3    No diabetes
# 4    No diabetes
# ..           ...
# 385  No diabetes
# 386     Diabetes
# 387  No diabetes
# 388     Diabetes
# 389  No diabetes
#
# [390 rows x 15 columns]

# %% [markdown]
# - Features Encoding

# %%
#Gender : male -> 1 and female -> 0

df['Gender'] = [1 if col=='male' else 0 if col=='female' else None for col in df['Gender']]


#Diabetes : Diabetes -> 1 and No Diabetes -> 0 

df['Diabetes'] = [1 if col=='Diabetes' else 0 if col=='No diabetes' else None for col in df['Diabetes']]

# %% [markdown]
# - Outliers, and perform exploratory data analysis (EDA).

# %% [markdown]
# **NB:** Outlier handling will be employed in the preprocessing step using StandardScaler, which is less sensitive to outliers.

# %%
DataViz.univariate_analysis_plots(df)

# %% [markdown]
#  - Correlation matrices

# %%
# Create a correlation matrix for all features
correlation_matrix = df.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix - All Features')
plt.show()

# %% [markdown]
# **NB:**
# - a) We can observe a **strong positive correlation** between these features, such as between cholesterol levels and diabetes outcomes, BMI and hip weight, hip weight and waist, as well as BMI and waist.
# - b) The **high negative correlation** signifies that as HDL cholesterol increases, the Chol/HDL ratio tends to decrease, and vice versa, emphasizing the interconnected impact on cardiovascular health.
#
#
#     - Features descriptions :
#         1. **Cholesterol Levels:** The measure of fats in the blood.
#         2. **Diabetes Outcomes:** The occurrence and severity of diabetes.
#         3. **BMI (Body Mass Index):** A measure of body fat based on height and weight.
#         4. **Hip Weight:** The weight around the hips.
#         5. **Waist:** The circumference around the waist.
#         6. **HDL Cholesterol (High-Density Lipoprotein):** Known as "good cholesterol," HDL helps remove other cholesterol from the bloodstream, promoting cardiovascular health.
#         7. **Chol/HDL Ratio (Total Cholesterol to HDL Cholesterol Ratio):** This ratio reflects the balance between total cholesterol and HDL cholesterol. A lower ratio is considered healthier, correlating with a reduced risk of cardiovascular issues.

# %% [markdown]
# ## 2. Feature Engineering and Data Preprossessing:
# - Data Preprossessing
# ____

# %% [markdown]
# - Data Preprossessing

# %%
#Separe Features and Target 

X = df.drop('Diabetes',axis=1)
y = df['Diabetes']

# %%
# Initialize a StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled , columns=X.columns)

# %% [markdown]
# **NB:**
# - **StandardScaler** is less sensitive to outliers because it uses the mean and standard deviation for scaling.
# - Outliers influence the mean more but have a smaller impact on the standard deviation, making StandardScaler more robust compared to methods relying on data range.

# %%
X_scaled
# Out:
#      Cholesterol   Glucose  HDL Chol  Chol/HDL ratio       Age    Gender  \
# 0      -0.319013 -0.564655 -0.073401       -0.360132 -1.692029 -0.842927
# 1      -1.372619 -0.527432 -0.536983       -0.533102 -1.692029 -0.842927
# 2       0.218998 -0.601879  0.216339       -0.302476 -1.631108 -0.842927
# 3       0.420753 -0.192418  1.143504       -0.763729 -1.631108 -0.842927
# 4      -0.969111 -0.304089  0.969660       -1.224982 -1.631108 -0.842927
# ..           ...       ...       ...             ...       ...       ...
# 385     0.443170 -0.043523 -0.363140        0.389404  2.206885 -0.842927
# 386     0.420753  3.194941  0.100443       -0.129506  2.267806 -0.842927
# 387     2.102039 -0.322701  3.924999       -1.109668  2.572409 -0.842927
# 388     0.555256  1.426814  3.693208       -1.455608  2.694250 -0.842927
# 389    -0.946693 -0.248254  1.085556       -1.224982  2.755170 -0.842927
#
#        Height    Weight       BMI  Systolic BP  Diastolic BP     waist  \
# 0   -1.265070 -1.447312 -0.951944    -0.838071     -0.985822 -1.020105
# 1   -1.520574 -1.050840 -0.360358    -1.276087     -1.875972 -0.846299
# 2    0.267951  0.237692  0.079539    -1.188484     -0.837464  0.370339
# 3   -0.498560 -1.571209 -1.391841    -0.662865     -1.430897 -1.193910
# 4    1.034462 -0.902163 -1.300828    -0.662865      0.201045 -1.020105
# ..        ...       ...       ...          ...           ...       ...
# 385 -1.776077 -1.298635 -0.542385     0.563581      0.497761 -0.498688
# 386 -1.520574  0.361590  1.323387     0.300771      0.349403  0.544145
# 387 -1.265070 -1.546430 -1.073295     3.542092      0.497761 -1.193910
# 388 -1.265070 -1.249076 -0.724411     1.439613     -0.095672 -0.498688
# 389 -1.009567  0.981076  1.657102     1.001597     -0.095672  2.282200
#
#           hip  Waist/hip ratio
# 0   -0.882489        -0.565995
# 1   -0.528950        -0.702760
# 2    0.354899         0.117828
# 3   -0.705719        -1.249818
# 4   -0.705719        -0.839524
# ..        ...              ...
# 385 -0.528950        -0.018937
# 386  0.885209        -0.429231
# 387 -0.352180        -1.660112
# 388 -0.882489         0.528122
# 389  1.415518         1.622239
#
# [390 rows x 14 columns]

# %% [markdown]
# ## 3. Ensemble Model Implementation:
# - Implement ensemble models: Gradient Boosting, Random Forests, Bagging, Voting, and Stacking.
# - Split the dataset into training and testing sets.
# - Train and tune each ensemble model using appropriate hyperparameter tuning.
# ______

# %% [markdown]
# - Implement ensemble models: Gradient Boosting, Random Forests, Bagging, Voting, and Stacking.

# %%
# Split Dataset into training and test sets

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Initialize individual models : ad votins
random_forest_model = RandomForestClassifier(n_estimators=100, random_state=42)
gradient_boosting_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
bagging_model = BaggingClassifier(base_estimator=LogisticRegression(), n_estimators=100, random_state=42)

# %%
# Train individual models
random_forest_model.fit(X_train, y_train)
gradient_boosting_model.fit(X_train, y_train)
bagging_model.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=LogisticRegression(), n_estimators=100,
#                   random_state=42)

# %%
# Initialize individual models
random_forest_model = RandomForestClassifier(n_estimators=100, random_state=42)
gradient_boosting_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
xgboost_model = XGBClassifier(n_estimators=100, random_state=42)
adaboost_model = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1), n_estimators=100, random_state=42)

# %%
# Train individual models
random_forest_model.fit(X_train, y_train)
gradient_boosting_model.fit(X_train, y_train)
xgboost_model.fit(X_train, y_train)
adaboost_model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1),
#                    n_estimators=100, random_state=42)

# %%
# Make predictions on the test set
rf_predictions = random_forest_model.predict(X_test)
gb_predictions = gradient_boosting_model.predict(X_test)
xgboost_predictions = xgboost_model.predict(X_test)
adaboost_predictions = adaboost_model.predict(X_test)

# %%
# Evaluate individual models
print("Random Forest Accuracy:", accuracy_score(y_test, rf_predictions))
print("Gradient Boosting Accuracy:", accuracy_score(y_test, gb_predictions))
print("XGBoost Accuracy:", accuracy_score(y_test, xgboost_predictions))
print("AdaBoost Accuracy:", accuracy_score(y_test, adaboost_predictions))
# Out:
# Random Forest Accuracy: 0.9102564102564102
# Gradient Boosting Accuracy: 0.8974358974358975
# XGBoost Accuracy: 0.9230769230769231
# AdaBoost Accuracy: 0.9102564102564102

# %%
# Ensemble using VotingClassifier (Hard and Soft Voting)
voting_classifier_hard = VotingClassifier(estimators=[
    ('random_forest', random_forest_model),
    ('gradient_boosting', gradient_boosting_model),
    ('xgboost', xgboost_model),
    ('adaboost', adaboost_model)
], voting='hard')

# %%
voting_classifier_soft = VotingClassifier(estimators=[
    ('random_forest', random_forest_model),
    ('gradient_boosting', gradient_boosting_model),
    ('xgboost', xgboost_model),
    ('adaboost', adaboost_model)
], voting='soft')

# %%
# Fit and predict with hard voting
voting_classifier_hard.fit(X_train, y_train)
voting_predictions_hard = voting_classifier_hard.predict(X_test)

# Fit and predict with soft voting
voting_classifier_soft.fit(X_train, y_train)
voting_predictions_soft = voting_classifier_soft.predict(X_test)

# %%
# Evaluate VotingClassifier (Hard and Soft Voting)
print("Hard Voting Classifier Accuracy:", accuracy_score(y_test, voting_predictions_hard))
print("Soft Voting Classifier Accuracy:", accuracy_score(y_test, voting_predictions_soft))
# Out:
# Hard Voting Classifier Accuracy: 0.8974358974358975
# Soft Voting Classifier Accuracy: 0.8974358974358975
