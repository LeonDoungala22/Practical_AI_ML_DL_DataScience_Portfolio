# %% [markdown]
# #  Logistic Regression (sigmoid functions)

# %% [markdown]
# [- Understanding Logistic Regression : By Abhigyan](https://medium.com/analytics-vidhya/understanding-logistic-regression-b3c672deac04)

# %% [markdown]
# [- Régression logistique, fonction coût, gradient descent, limite de décision: By Engineering life](https://www.youtube.com/watch?v=QqAUqRAWEV8)

# %% [markdown]
# [- Sklearn documentation : Logistic regression](https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression)

# %% [markdown]
# It's a **Binary Classification** algorithm not a regression algorithm

# %% [markdown]
# ![logistic-regression-in-machine-learning.png](attachment:logistic-regression-in-machine-learning.png)

# %% [markdown]
# The **Logistic Regression** is done using the **LogisticRegression** module. Even though it's called **"regression,"** it's actually used as a linear model for classification, not regression, according to the scikit-learn/machine learning terms.

# %% [markdown]
# ## Types of Logistic Regression:

# %% [markdown]
# - **Binary Logistic Regression:** The dependent variable has only two 2 possible outcomes/classes. **Example-Male or Female.**
# - **Multinomial Logistic Regression:** The dependent variable has only two 3 or more possible outcomes/classes without ordering.**Example: Predicting food quality.(Good,Great and Bad).**
# - **Ordinal Logistic Regression:** The dependent variable has only two 3 or more possible outcomes/classes with ordering. **Example: Star rating from 1 to 5**

# %% [markdown]
# ![Screenshot%202024-01-04%20at%2012.53.31.png](attachment:Screenshot%202024-01-04%20at%2012.53.31.png)

# %% [markdown]
# ![Screenshot%202024-01-04%20at%2012.59.31.png](attachment:Screenshot%202024-01-04%20at%2012.59.31.png)

# %% [markdown]
# ![Screenshot%202024-01-04%20at%2013.02.05.png](attachment:Screenshot%202024-01-04%20at%2013.02.05.png)

# %% [markdown]
# ![Screenshot%202024-01-04%20at%2013.09.32.png](attachment:Screenshot%202024-01-04%20at%2013.09.32.png)
