# %% [markdown]
# # Naive Bayes

# %% [markdown]
# [SKlearn Documentation](https://scikit-learn.org/stable/modules/naive_bayes.html)

# %% [markdown]
# [Classification・Naive Bayes Classifier](https://www.kaggle.com/code/samybaladram/04-3-classification-naive-bayes-classifier)

# %% [markdown]
# ## - Definitions

# %% [markdown]
# **Naive Bayes methods** are a set of supervised learning algorithms based on applying **Bayes’ theorem** with the “naive” assumption of conditional independence between every pair of features given the value of the class variable. Bayes’ theorem states the following relationship, given class variable
#  and dependent feature vector
#  through
# , :

# %% [markdown]
# ![1_39U1Ln3tSdFqsfQy6ndxOA.png](attachment:1_39U1Ln3tSdFqsfQy6ndxOA.png)

# %% [markdown]
# ![1533388073998.png](attachment:1533388073998.png)

# %% [markdown]
# **NB:**
#
# - Naive Bayes learners and classifiers can be **extremely fast compared to more sophisticated methods**. The decoupling of the class conditional feature distributions means that each distribution can be independently estimated as a one dimensional distribution. This in turn helps to alleviate problems stemming from the curse of dimensionality.
#
# - On the flip side, although naive Bayes is known as a decent classifier, it is known to be a bad estimator, so the probability outputs from predict_proba are not to be taken too seriously.

# %% [markdown]
# ## - Naive Bayes: Pros and Cons
#
# | **Pros**                               | **Cons**                                     |
# |----------------------------------------|----------------------------------------------|
# | Simple to understand and implement.    | Assumes independence of features.            |
# | Requires a small amount of data.       | May not perform well with complex data.      |
# | Fast prediction speed.                 | Less accurate in certain situations.         |
# | Low computational resource usage.      | Sensitive to irrelevant features.            |
# | Effective for text classification.     | Limited for tasks with complex dependencies.|
# | Robust to irrelevant features.         | Assumes features are conditionally independent.|
# | Works well with a large number of features. | Struggles with extremely high-dimensional data. |

# %% [markdown]
# ## - Types of Naive Bayes Algorithms

# %% [markdown]
# ![1PZX4ay.png](attachment:1PZX4ay.png)

# %% [markdown]
# ### a ) Gaussian Naive Bayes

# %% [markdown]
# **GaussianNB** implements the Gaussian Naive Bayes algorithm for classification. The likelihood of the features is assumed to be Gaussian .
#
# Gaussian Naive Bayes is a **classification technique** used in machine learning based on the probabilistic approach and **Gaussian distribution.**

# %% [markdown]
# ![C3.png](attachment:C3.png)

# %% [markdown]
# ![preview.jpeg](attachment:preview.jpeg)

# %% [markdown]
# **Normal distribution**, also known as the **Gaussian distribution**, is a probability distribution that is symmetric about the **mean**, showing that data near the mean are more frequent in occurrence than data far from the mean. In graphical form, the normal distribution appears as a **"bell curve".**

# %% [markdown]
# ![standard-normal-distribution-example.webp](attachment:standard-normal-distribution-example.webp)

# %% [markdown]
# ![dotdash_final_Optimize_Your_Portfolio_Using_Normal_Distribution_23-0701d4f1047045a392ba624b68a8b8be.jpeg](attachment:dotdash_final_Optimize_Your_Portfolio_Using_Normal_Distribution_23-0701d4f1047045a392ba624b68a8b8be.jpeg)

# %% [markdown]
# ### b ) Multinomial naive bayes

# %% [markdown]
# **MultinomialNB**
#
# - **Multinomial Naive Bayes** algorithm is a probabilistic learning method that is mostly used in **Natural Language Processing (NLP).** The algorithm is based on the Bayes theorem and **predicts the tag of a text** such as a piece of email or newspaper article
#
#
# - The Gaussian and Multinomial models of the naïve Bayes exist. **The multinomial model provides an ability to classify data, that cannot be represented numerically**. Its main advantage is the significantly reduced complexity.

# %% [markdown]
# ![uaPM4.png](attachment:uaPM4.png)

# %% [markdown]
# ### b ) Bernoulli naive bayes

# %% [markdown]
# **BernoulliNB**( On sklean )
#
#
# **Bernoulli Naive Bayes** is a part of the Naive Bayes family. It is based on the **Bernoulli Distribution** and **accepts only binary values**, i.e., **0 or 1.** If **the features of the dataset are binary**, then we can assume that Bernoulli Naive Bayes is the algorithm to be used

# %% [markdown]
# ![11-1.jpeg](attachment:11-1.jpeg)

# %% [markdown]
# ![tab.png](attachment:tab.png)
